# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def crawl(url):
    headers={
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36"
    }

    response =requests.get(url,headers=headers)
    soup=BeautifulSoup(response.text,'html.parser')

    product=[]
    price=[]
    ratings=[]

    p_name=soup.find_all('span',class_="a-size-medium a-color-base a-text-normal")
    p_price=soup.find_all('span',class_="a-price-whole")
    p_rating=soup.find_all('span',class_="a-size-base s-underline-text")

    for i in p_name:
        product.append(i.text)

    for i in p_price:
        price.append(i.text)

    for i in p_rating:
        ratings.append(i.text)

    min_len=min(len(product),len(price),len(ratings))
    product=product[:min_len]
    price=price[:min_len]
    ratings=ratings[:min_len]

    df=pd.DataFrame({'Product':product,'Price':price,'Ratings':ratings,})
    return df

# %%
df=crawl("https://www.amazon.in/s?k=mobile+phones+under+15000&crid=2XATADS7OZOX4&sprefix=mobile+phones+under+%2Caps%2C208&ref=nb_sb_ss_ts-doa-p_2_20")

# %%
df
# Out:
#                                               Product   Price Ratings
# 0   Samsung Galaxy M35 5G (Daybreak Blue,6GB RAM,1...  18,999   4,572
# 1   Samsung Galaxy M05 (Mint Green, 4GB RAM, 64 GB...   7,999     717
# 2   realme NARZO N65 5G (Deep Green 6GB RAM, 128GB...  12,498   1,494
# 3   Samsung Galaxy M15 5G Prime Edition (Blue Topa...  14,999     608
# 4   realme NARZO 70x 5G (Ice Blue, 6GB RAM,128GB S...  12,998   3,388
# 5   Redmi 13 5G, Orchid Pink, 6GB+128GB | India De...  12,999   2,172
# 6   Redmi 13C 5G (Starlight Black, 4GB RAM, 128GB ...   9,199   9,995
# 7   iQOO Z9x 5G (Tornado Green, 6GB RAM, 128GB Sto...  13,999   4,439
# 8   iQOO Z9 Lite 5G (Mocha Brown, 6GB RAM, 128GB S...  11,498   1,953
# 9   Redmi 13C 5G (Startrail Green, 4GB RAM, 128GB ...   9,199   9,995
# 10  Redmi 13 5G, Orchid Pink, 6GB+128GB | India De...  12,999   2,172
# 11  Samsung Galaxy S23 Ultra 5G AI Smartphone (Gre...  79,999   2,449
# 12  Nokia G42 5G | Snapdragon® 480+ 5G | 50MP Trip...  11,499   5,428
# 13  iQOO Z9x 5G (Storm Grey, 6GB RAM, 128GB Storag...  13,999   4,439
# 14  Samsung Galaxy F15 5G (Ash Black, 6GB RAM, 128...  13,993     107
# 15  realme NARZO 70x 5G (Ice Blue, 8GB RAM,128GB S...  13,999   3,388
# 16  realme 12X 5G (Woodland Green, 8GB RAM, 128GB ...  12,655      93
# 17  realme NARZO N65 5G (Deep Green 4GB RAM, 128GB...  11,498   1,494
# 18  Samsung Galaxy M05 (Mint Green, 4GB RAM, 64 GB...   7,999     717
# 19  Samsung Galaxy M14 5G (Smoky Teal,6GB,128GB)|5...  10,999   7,138
# 20  Samsung Galaxy M15 5G Prime Edition (Stone Gre...  14,999     608
# 21  IKALL K333 Touch & Type 4G Phone with 2GB RAM,...   2,875     234

# %%
df.to_csv('amazon_1.csv')

# %%
#for image crawler

# %%
def image_crawler(url):
    head = {
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36"}
    response = requests.get(url,headers = head)
    soup = BeautifulSoup(response.text,'html.parser')

    image = []
    im_data = soup.find_all('img',class_="s-image")

    for i in im_data:
        image.append(i.get('src'))
    return image

# %%
img=image_crawler("https://www.amazon.in/s?k=mobile+phones+under+15000&crid=2XATADS7OZOX4&sprefix=mobile+phones+under+%2Caps%2C208&ref=nb_sb_ss_ts-doa-p_2_20")

# %%
img
# Out:
# ['https://m.media-amazon.com/images/I/81oKOk65TgL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/81nJiu51M+L._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/81scQ7qlPuL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71qFJqFePsL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/81Q9jpYOFdL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/717sEAdy02L._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71w-mmKgIfL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/81nMsYgIHdL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/619VJYWIbXL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71oIjjNm+nL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/81Q9jpYOFdL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71lD7eGdW-L._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/717yx8s4prL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/81KFSdWCCEL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/61wHkeTOhWL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71w-mmKgIfL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/61sY8BGOyEL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/717sEAdy02L._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/81dl4dQY3BL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/718RrecpkVL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/81T3olLXpUL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/51ePjiVREFL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/61UCO92a1qL._AC_UL640_QL65_.jpg',
#  'https://m.media-amazon.com/images/I/61UCO92a1qL._AC_UL640_QL65_.jpg']

# %%
import os
os.makedirs('amazon',exist_ok=True)

# %%
i=0
for j in img:
    try:
        resp=requests.get(j)
        with open(f"amazon/{i}.jpg","wb") as f:
            f.write(resp.content)
        i+=1
    except:
        pass
